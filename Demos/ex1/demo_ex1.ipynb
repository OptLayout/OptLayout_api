# %%
# %%
import sys
import os
print(os.getcwd())
parentpath=os.getcwd().split("Demos") [0]
sys.path.append(parentpath)

from CLS_OptField import OptField

# # .ipynb does not need this
# from multiprocessing import freeze_support
# if __name__ == '__main__':
#     freeze_support()
# Out:
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\Demos\ex1

# %%
# %%
filepath=parentpath+"\\Demos\\ex1\\input_ex1.json"
print("//////////////////////////////")
print("executing on the following file:")
print(filepath)
print("//////////////////////////////")
# Out:
# //////////////////////////////
# executing on the following file:
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\\Demos\ex1\input_ex1.json
# //////////////////////////////

# %%
# %%
# initialize a class instance
myfield=OptField(filepath)

# %%
# %%
# compute all cost contours as satellites
myfield.get_contours()
# simple visualization of the contours
myfield.plot_contours()

# %%
# %%
# check one cluster, i.e., 1-site-N-wells
myfield.get_1site([0,25,26])
# simple visualization of the 1-site-N-wells trajectories
myfield.plot_1site()
# Out:
# optimal site:
#  soluPK =[810.28321744 531.60610076]
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\AsiteNwells\CostContour\GetContours.py:189: RuntimeWarning: invalid value encountered in multiply
#   Contour_ValM=np.empty((PCM.shape[0], X.shape[0], X.shape[1]))*np.nan

# %%
# %%
# show the cost contour of the 1-site-N-wells problem
myfield.plot_1site(showContour=1)

# %%
# %%
myfield.soluList_1site[1]
# Out:
# {'r': array([572.95779513]),
#  'r1': 572.9577951308232,
#  'r2': 572.9577951308232,
#  'P1': array([ 810.28321744,  531.60610076, -500.        ]),
#  'P2': array([ 1071.,  1714., -2500.]),
#  'V1': array([ 0.,  0., -1.]),
#  'V2': array([ 429., 1000.,    0.]),
#  'v1': array([ 0.,  0., -1.]),
#  'v2': array([0.39425202, 0.91900237, 0.        ]),
#  'T': array([   84.67742622,   632.34447534, -1420.90461892]),
#  'Ls': 1557.562113712425,
#  't': array([ 0.05436536,  0.40598347, -0.91226193]),
#  'P1O1': array([ 76.04614043, 567.88873869,   0.        ]),
#  'p1o1': array([0.13272555, 0.99115283, 0.        ]),
#  'O1': array([ 886.32935787, 1099.49483945, -500.        ]),
#  'C1O1': array([ 69.37399878, 518.0632764 , 234.68771791]),
#  'c1o1': array([0.12108047, 0.90419099, 0.40960734]),
#  'C1': array([ 816.95535908,  581.43156304, -734.68771791]),
#  'P2O2': array([ 63.08974526, -27.06550072, 568.83018355]),
#  'p2o2': array([ 0.11011238, -0.04723821,  0.99279596]),
#  'O2': array([ 1134.08974526,  1686.93449928, -1931.16981645]),
#  'C2O2': array([232.45695995, 473.1584609 , 224.42252037]),
#  'c2o2': array([0.40571393, 0.8258173 , 0.39169119]),
#  'C2': array([  901.6327853 ,  1213.77603839, -2155.59233682]),
#  'theta1': 0.4220235950095165,
#  'theta2': 1.1652362954867754,
#  'L1': 241.80170848983605,
#  'L2': 667.6312186685112,
#  'L': 2466.9950408707723,
#  'error': 0}

# %%
# %%
# compute KsitesNwells
myfield.get_Ksites()
# simple visualization of K-sites-N-wells
myfield.plot_Ksites()
# Out:
# selected 10 clusters:
# [  5  18  54  70  89  92 144 272 329 337]
#
# The optimal combination:
# [(1, 2, 8, 24), (3, 4, 5, 6), (9, 12, 22, 28), (11, 14, 18, 20), (15, 16, 19, 29), (0, 25, 26), (7, 23, 27), (10, 17), (13,), (21,)]
#
# The optimal cost:92754.81595020716

# %%
myfield.plot_Ksites(showContour=1,plotz=0) # show cost contour on the plane Z=plotz

# %%
from AsiteNwells.Visualization.PlotContour import  PlotContours
PlotContours(myfield.X, myfield.Y, myfield.Contour_ValM_Ksites, ax=None, freeze=0,
                        separate=1, show=1, plotz=0)
# Out:
# <Axes3D: xlabel='X', ylabel='Y', zlabel='Z'>

# %%
# re-define the constraints on cluster numbers
# and compare the optimal layout
myfield.cluster_max=20

# compute KsitesNwells
myfield.get_Ksites()
# simple visualization of K-sites-N-wells
myfield.plot_Ksites(showContour=1,plotz=0)
# Out:
# selected 14 clusters:
# [ 89  92  95 117 141 169 263 293 312 329 333 337 339 340]
#
# The optimal combination:
# [(15, 16, 19, 29), (0, 25, 26), (1, 2, 8), (3, 4, 5), (6, 7, 27), (10, 11, 20), (9, 12), (14, 18), (22, 28), (13,), (17,), (21,), (23,), (24,)]
#
# The optimal cost:90891.54483634265

# %%
# %%
# save 1-site-N-wells results to json file
myfield.write_json_1site(filepath=".\\results\\ex1_traj_.json")
# Out:
# =====file .\results\ex1_traj_1.json written successfully=====
# ===================================
# =====file .\results\ex1_traj_26.json written successfully=====
# ===================================
# =====file .\results\ex1_traj_27.json written successfully=====
# ===================================

# %%
# %%
# save 1-site-N-wells results to excel file
myfield.write_excel_1site(filepath_excel="\\ex1_output.xls", sheetname="Atraj_No_")
# Out:
# =====sheet: Atraj_No_1 written successfully=====
# ===================================
# =====sheet: Atraj_No_26 written successfully=====
# ===================================
# =====sheet: Atraj_No_27 written successfully=====
# ===================================

# %%
# %%
# save cost contours of satellites to json file
myfield.write_json_contours(filepath="\\results\\ex1_cstcontour_.json")
# Out:
# =====file .\results\ex1_cstcontour_1.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_2.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_3.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_4.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_5.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_6.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_7.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_8.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_9.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_10.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_11.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_12.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_13.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_14.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_15.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_16.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_17.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_18.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_19.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_20.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_21.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_22.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_23.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_24.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_25.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_26.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_27.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_28.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_29.json written successfully=====
# ===================================
# =====file .\results\ex1_cstcontour_30.json written successfully=====
# ===================================

# %%
# %%
# save cost contours of satellites to excel file
myfield.write_excel_contours("ex1_output.xls")
# Out:
# =====sheet: CostContour_NO_1 written successfully=====
# ===================================
# =====sheet: CostContour_NO_2 written successfully=====
# ===================================
# =====sheet: CostContour_NO_3 written successfully=====
# ===================================
# =====sheet: CostContour_NO_4 written successfully=====
# ===================================
# =====sheet: CostContour_NO_5 written successfully=====
# ===================================
# =====sheet: CostContour_NO_6 written successfully=====
# ===================================
# =====sheet: CostContour_NO_7 written successfully=====
# ===================================
# =====sheet: CostContour_NO_8 written successfully=====
# ===================================
# =====sheet: CostContour_NO_9 written successfully=====
# ===================================
# =====sheet: CostContour_NO_10 written successfully=====
# ===================================
# =====sheet: CostContour_NO_11 written successfully=====
# ===================================
# =====sheet: CostContour_NO_12 written successfully=====
# ===================================
# =====sheet: CostContour_NO_13 written successfully=====
# ===================================
# =====sheet: CostContour_NO_14 written successfully=====
# ===================================
# =====sheet: CostContour_NO_15 written successfully=====
# ===================================
# =====sheet: CostContour_NO_16 written successfully=====
# ===================================
# =====sheet: CostContour_NO_17 written successfully=====
# ===================================
# =====sheet: CostContour_NO_18 written successfully=====
# ===================================
# =====sheet: CostContour_NO_19 written successfully=====
# ===================================
# =====sheet: CostContour_NO_20 written successfully=====
# ===================================
# =====sheet: CostContour_NO_21 written successfully=====
# ===================================
# =====sheet: CostContour_NO_22 written successfully=====
# ===================================
# =====sheet: CostContour_NO_23 written successfully=====
# ===================================
# =====sheet: CostContour_NO_24 written successfully=====
# ===================================
# =====sheet: CostContour_NO_25 written successfully=====
# ===================================
# =====sheet: CostContour_NO_26 written successfully=====
# ===================================
# =====sheet: CostContour_NO_27 written successfully=====
# ===================================
# =====sheet: CostContour_NO_28 written successfully=====
# ===================================
# =====sheet: CostContour_NO_29 written successfully=====
# ===================================
# =====sheet: CostContour_NO_30 written successfully=====
# ===================================

# %%
# %%
# save cost contours of 1-site-N-well to json file
# Use ClusterNO to identify different clusters
myfield.write_json_contour1site("ex1_cstcontour_cluster_.json",
                                ClusterNO=1)
# Out:
# =====file ex1_cstcontour_cluster_1.json written successfully=====
# ===================================

# %%
# %%
# save cost contours of 1-site-N-well to json file
# Use ClusterNO to identify different clusters
myfield.write_excel_contour1site("ex1_output.xls",
                                ClusterNO=1)
# Out:
# =====CostContour_NO_1 written successfully=====
# ===================================

# %%
# %%
# save K-sites-N-wells results to json file
myfield.write_json_Ksites(".\\results\\ex1_Ktraj_.json")
# Out:
# =====file .\results\ex1_Ktraj_1.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_2.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_3.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_4.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_5.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_6.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_7.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_8.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_9.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_10.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_11.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_12.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_13.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_14.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_15.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_16.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_17.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_18.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_19.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_20.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_21.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_22.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_23.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_24.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_25.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_26.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_27.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_28.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_29.json written successfully=====
# ===================================
# =====file .\results\ex1_Ktraj_30.json written successfully=====
# ===================================

# %%
# %%
# save K-sites-N-wells results to json file
myfield.write_excel_Ksites("ex1_output.xls", "Ktraj_No_")
# Out:
# =====sheet: Ktraj_No_1 written successfully=====
# ===================================
# =====sheet: Ktraj_No_2 written successfully=====
# ===================================
# =====sheet: Ktraj_No_3 written successfully=====
# ===================================
# =====sheet: Ktraj_No_4 written successfully=====
# ===================================
# =====sheet: Ktraj_No_5 written successfully=====
# ===================================
# =====sheet: Ktraj_No_6 written successfully=====
# ===================================
# =====sheet: Ktraj_No_7 written successfully=====
# ===================================
# =====sheet: Ktraj_No_8 written successfully=====
# ===================================
# =====sheet: Ktraj_No_9 written successfully=====
# ===================================
# =====sheet: Ktraj_No_10 written successfully=====
# ===================================
# =====sheet: Ktraj_No_11 written successfully=====
# ===================================
# =====sheet: Ktraj_No_12 written successfully=====
# ===================================
# =====sheet: Ktraj_No_13 written successfully=====
# ===================================
# =====sheet: Ktraj_No_14 written successfully=====
# ===================================
# =====sheet: Ktraj_No_15 written successfully=====
# ===================================
# =====sheet: Ktraj_No_16 written successfully=====
# ===================================
# =====sheet: Ktraj_No_17 written successfully=====
# ===================================
# =====sheet: Ktraj_No_18 written successfully=====
# ===================================
# =====sheet: Ktraj_No_19 written successfully=====
# ===================================
# =====sheet: Ktraj_No_20 written successfully=====
# ===================================
# =====sheet: Ktraj_No_21 written successfully=====
# ===================================
# =====sheet: Ktraj_No_22 written successfully=====
# ===================================
# =====sheet: Ktraj_No_23 written successfully=====
# ===================================
# =====sheet: Ktraj_No_24 written successfully=====
# ===================================
# =====sheet: Ktraj_No_25 written successfully=====
# ===================================
# =====sheet: Ktraj_No_26 written successfully=====
# ===================================
# =====sheet: Ktraj_No_27 written successfully=====
# ===================================
# =====sheet: Ktraj_No_28 written successfully=====
# ===================================
# =====sheet: Ktraj_No_29 written successfully=====
# ===================================
# =====sheet: Ktraj_No_30 written successfully=====
# ===================================
