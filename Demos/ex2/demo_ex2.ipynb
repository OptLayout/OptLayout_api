# %%
# %%

import sys
import os
# parentpath=os.getcwd().split("Subsea_Field_Layout_Opt") [0] + "Subsea_Field_Layout_Opt"
parentpath=os.getcwd().split("Demos") [0]
sys.path.append(parentpath)

from CLS_OptField import OptField

# # .ipynb does not need this
# from multiprocessing import freeze_support
# if __name__ == '__main__':
#     freeze_support()

# %%
# %%
filepath=parentpath+"\\Demos\\ex2\\input_heiss.json"
print("//////////////////////////////")
print("executing on the following file:")
print(filepath)
print("//////////////////////////////")
# Out:
# //////////////////////////////
# executing on the following file:
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\\Demos\ex2\input_heiss.json
# //////////////////////////////

# %%
# %%
# initialize a class instance
myfield=OptField(filepath)

# %%
# %%
# compute all cost contours as satellites
myfield.get_contours()
# simple visualization of the contours
myfield.plot_contours()

# %%
# %%
# check one cluster, i.e., 1-site-N-wells
myfield.get_1site()
myfield.plot_1site()
# Out:
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\AsiteNwells\Dubins3D_2P\Dubins2P.py:52: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   T = opt.fsolve( func, x0=T0,  args=(P1, P2, V1, V2, r))
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\AsiteNwells\Dubins3D_2P\Dubins2P.py:52: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   T = opt.fsolve( func, x0=T0,  args=(P1, P2, V1, V2, r))
# optimal site:
#  soluPK =[ 516461.64623127 6782340.26520238]
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\AsiteNwells\CostContour\GetContours.py:189: RuntimeWarning: invalid value encountered in multiply
#   Contour_ValM=np.empty((PCM.shape[0], X.shape[0], X.shape[1]))*np.nan

# %%
# %%
# show the cost contour of the 1-site-N-wells problem
myfield.plot_1site(showContour=1)

# %%
# %%
myfield.soluList_1site[0]
# Out:
# {'r': 572.9577951308232,
#  'P1': array([ 5.16461646e+05,  6.78234027e+06, -4.00000000e+02]),
#  'P2': array([ 5.1716790e+05,  6.7825139e+06, -1.5500000e+03]),
#  'V1': array([ 0.,  0., -1.]),
#  'V2': array([968.2, 636.1, -14. ]),
#  'v1': array([ 0.,  0., -1.]),
#  'v2': array([ 0.83570218,  0.54904994, -0.01208411]),
#  'T': array([ 162.17073062,  -40.05121163, -533.55852603]),
#  'Ls': 559.0958291018912,
#  't': array([ 0.29005892, -0.07163568, -0.95432392]),
#  'PO1': array([162.17073062, -40.05121163,   0.        ]),
#  'po1': array([ 0.97083083, -0.23976553,  0.        ]),
#  'O1': array([ 5.17017891e+05,  6.78220289e+06, -4.00000000e+02]),
#  'CO1': array([ 86527.57599252, -21369.66544393,  27903.44542179]),
#  'co1': array([ 0.92648708, -0.22881398,  0.29877391]),
#  'C1': array([ 5.16487053e+05,  6.78233399e+06, -5.71184838e+02]),
#  'PO2': array([-8.30839686e+07,  1.42180274e+08,  7.14212403e+08]),
# [0.06406963] [ 516028.07018624 6782424.2326467 ]
# [0.06407003] [ 516028.07029366 6782424.23200352]
# [0.06406962] [ 516028.07057837 6782424.23228854]
# [0.06406981] [ 516028.07029719 6782424.23230135]
# [0.06406987] [ 516028.07031987 6782424.23219187]
# [0.06406974] [ 516028.07045681 6782424.2322442 ]
# optimal site:
#  soluPK =[ 516028.07045681 6782424.2322442 ]
# d:\OneDrive\OneDrive - LHG\Projects\OptLayout_GUI\AsiteNwells\Dubins3D_2P\Dubins2P.py:52: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   T = opt.fsolve( func, x0=T0,  args=(P1, P2, V1, V2, r))

# %%
# %%
# check one cluster, i.e., 1-site-N-wells
myfield.get_1site([0,1,2])
myfield.plot_1site()
# Out:
# optimal site:
#  soluPK =[ 516702.83944175 6782333.60229119]

# %%
myfield.soluList_1site[0]
# Out:
# {'r': 572.9577951308232,
#  'P1': array([ 5.16702839e+05,  6.78233360e+06, -4.00000000e+02]),
#  'P2': array([ 5.1716790e+05,  6.7825139e+06, -1.5500000e+03]),
#  'V1': array([ 0.,  0., -1.]),
#  'V2': array([968.2, 636.1, -14. ]),
#  'v1': array([ 0.,  0., -1.]),
#  'v2': array([ 0.83570218,  0.54904994, -0.01208411]),
#  'T': array([ -31.93389734,  -64.87386775, -381.34785864]),
#  'Ls': 388.1424761657999,
#  't': array([-0.08227365, -0.16713932, -0.98249453]),
#  'PO1': array([-31.93389734, -64.87386775,  -0.        ]),
#  'po1': array([-0.44163942, -0.89719263, -0.        ]),
#  'O1': array([ 5.16449799e+05,  6.78181955e+06, -4.00000000e+02]),
#  'CO1': array([-12177.92336681, -24739.51054744,   5228.39251565]),
#  'co1': array([-0.43390831, -0.88148685,  0.18629145]),
#  'C1': array([ 5.16698410e+05,  6.78232460e+06, -5.06737138e+02]),
#  'PO2': array([-2.18574509e+07,  4.45550694e+07,  5.12792549e+08]),
#  'po2': array([-0.04242613,  0.08648306,  0.99534954]),
#  'O2': array([ 5.17143592e+05,  6.78256345e+06, -9.79706723e+02]),
#  'CO2': array([370299.89790067, 235724.86839824, -71109.62405052]),
#  'co2': array([ 0.83272394,  0.53009396, -0.15991008]),
#  'C2': array([ 5.16666476e+05,  6.78225973e+06, -8.88084996e+02]),
#  'theta1': 0.18738615787160057,
#  'theta2': 1.7200008405323213,
#  'L1': 107.36435985214861,
#  'L2': 985.4878892145615,
#  'L': 1480.99472523251,
#  'error': 0}

# %%
# set turn angle contraint for the 1st well 
# so that its trajectory  won't have such a huge turn
myfield.necon=[ [' -theta2+pi/3'], ['nan'], ['nan'], ['nan']]
myfield.get_1site([0,1,2])
myfield.plot_1site()
# Out:
# [-0.69191082] [ 516800. 6782200.]
# [-0.69191082] [ 516800. 6782200.]
# [-0.72606306] [ 516815. 6782200.]
# [-0.71381623] [ 516800. 6782215.]
#  'T': array([ 343.57302593,   67.94744713, -562.30229641]),
#  'Ls': 662.4523773582407,
#  't': array([ 0.51863808,  0.10256956, -0.8488192 ]),
#  'PO1': array([343.57302593,  67.94744713,   0.        ]),
#  'po1': array([0.98099966, 0.19400947, 0.        ]),
#  'O1': array([ 5.16853412e+05,  6.78232475e+06, -4.00000000e+02]),
#  'CO1': array([193191.90146678,  38207.00555598, 122659.27972072]),
#  'co1': array([0.83269134, 0.16467897, 0.52868324]),
#  'C1': array([ 5.16376315e+05,  6.78223040e+06, -7.02913183e+02]),
#  'PO2': array([-8.96161343e+07,  1.52896522e+08,  7.49366890e+08]),
#  'po2': array([-0.11637879,  0.19855701,  0.97315522]),
#  'O2': array([ 5.17101220e+05,  6.78262766e+06, -9.92423128e+02]),
#  'CO2': array([442363.6945071 , 382025.81200422, 316452.40093213]),
#  'co2': array([0.66554992, 0.57476971, 0.47611247]),
#  'C2': array([ 5.16719888e+05,  6.78229835e+06, -1.26521548e+03]),
#  'theta1': 0.5570485289532365,
#  'theta2': 1.0471975511975962,
#  'L1': 319.165296929915,
#  'L2': 600.0000000005721,
#  'L': 1581.6176742887278,
#  'error': 0}

# %%
# %%
# save 1-site-N-wells results to json file
myfield.write_json_1site("heiss_traj_.json")
# Out:
# =====file heiss_traj_1.json written successfully=====
# ===================================
# =====file heiss_traj_2.json written successfully=====
# ===================================
# =====file heiss_traj_3.json written successfully=====
# ===================================

# %%
# %%
# save 1-site-N-wells results to excel file
myfield.write_excel_1site("heiss_output.xls")
# Out:
# =====sheet: WellTraj_No_1 written successfully=====
# ===================================
# =====sheet: WellTraj_No_2 written successfully=====
# ===================================
# =====sheet: WellTraj_No_3 written successfully=====
# ===================================

# %%
# %%
# save cost contours of satellites to json file
myfield.write_json_contours("heiss_cstcontour_.json")
# Out:
# =====file heiss_cstcontour_1.json written successfully=====
# ===================================
# =====file heiss_cstcontour_2.json written successfully=====
# ===================================
# =====file heiss_cstcontour_3.json written successfully=====
# ===================================
# =====file heiss_cstcontour_4.json written successfully=====
# ===================================

# %%
# %%
# save cost contours of satellites to excel file
myfield.write_excel_contours("heiss_output.xls")
# Out:
# =====sheet: CostContour_NO_1 written successfully=====
# ===================================
# =====sheet: CostContour_NO_2 written successfully=====
# ===================================
# =====sheet: CostContour_NO_3 written successfully=====
# ===================================
# =====sheet: CostContour_NO_4 written successfully=====
# ===================================

# %%
# %%
# save cost contours of 1-site-N-well to json file
# Use ClusterNO to identify different clusters
myfield.write_json_contour1site("heiss_cstcontour_cluster.json")
# Out:
# =====file heiss_cstcontour_cluster.json written successfully=====
# ===================================

# %%
# %%
# save cost contours of 1-site-N-well to json file
# Use ClusterNO to identify different clusters
myfield.write_excel_contour1site("heiss_output.xls",
                                ClusterNO=1)
# Out:
# =====CostContour_NO_1 written successfully=====
# ===================================
